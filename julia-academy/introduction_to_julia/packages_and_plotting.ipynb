# %%
using Pkg # can use from the REPL or inline, REPL is preferred
Pkg.add("Colors")
# Out:
#    Resolving package versions...
#     Updating `~/.julia/environments/v1.8/Project.toml`
#   [5ae59095] + Colors v0.12.8
#   No Changes to `~/.julia/environments/v1.8/Manifest.toml`

# %%
using Colors

# %%
palette = distinguishable_colors(100)
# Out:
# 100-element Array{RGB{N0f8},1} with eltype RGB{FixedPointNumbers.N0f8}:
#  RGB{N0f8}(0.0,0.0,0.0)
#  RGB{N0f8}(1.0,1.0,0.455)
#  RGB{N0f8}(1.0,0.608,1.0)
#  RGB{N0f8}(0.0,0.827,1.0)
#  RGB{N0f8}(0.886,0.388,0.051)
#  RGB{N0f8}(0.0,0.494,0.0)
#  RGB{N0f8}(0.0,0.314,0.902)
#  RGB{N0f8}(0.675,0.0,0.278)
#  RGB{N0f8}(0.0,1.0,0.784)
#  RGB{N0f8}(0.0,0.392,0.408)
#  ⋮
#  RGB{N0f8}(0.714,0.976,0.851)
#  RGB{N0f8}(0.855,0.0,0.247)
#  RGB{N0f8}(0.18,0.129,0.141)
#  RGB{N0f8}(0.0,0.345,0.082)
#  RGB{N0f8}(1.0,0.557,0.114)
#  RGB{N0f8}(0.4,0.455,0.694)
#  RGB{N0f8}(0.0,0.804,0.678)
#  RGB{N0f8}(0.0,0.498,0.388)
#  RGB{N0f8}(0.6,0.435,0.239)

# %%
using Plots

# %%
x = -3:0.1:3
f(x) = x ^ 2
y = f.(x)
# Out:
# 61-element Vector{Float64}:
#  9.0
#  8.41
#  7.839999999999999
#  7.290000000000001
#  6.760000000000001
#  6.25
#  5.76
#  5.289999999999999
#  4.840000000000001
#  4.41
#  ⋮
#  4.840000000000001
#  5.289999999999999
#  5.76
#  6.25
#  6.760000000000001
#  7.290000000000001
#  7.839999999999999
#  8.41
#  9.0

# %%
gr()
# Out:
# Plots.GRBackend()

# %%
plot(x, y, label="line")
scatter!(x, y, label="points")

# %%
# switch plot backends on the fly!
plotlyjs()
# Out:
# ┌ Warning: Module ColorSchemes with build ID 425166752110882 is missing from the cache.
# │ This may mean ColorSchemes [35d6a980-a343-548e-a6ea-1d62b119f2f4] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1325
# ┌ Warning: Module ColorSchemes with build ID 425166752110882 is missing from the cache.
# │ This may mean ColorSchemes [35d6a980-a343-548e-a6ea-1d62b119f2f4] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1325
# ┌ Warning: Module ColorSchemes with build ID 425166752110882 is missing from the cache.
# │ This may mean ColorSchemes [35d6a980-a343-548e-a6ea-1d62b119f2f4] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1325
# Plots.PlotlyJSBackend()

# %%
plot(x, y, label="line")
scatter!(x, y, label="points")

# %%
gr()
# Out:
# Plots.GRBackend()

# %%
global_temps = [14.4, 14.5, 14.8, 15.2, 15.5, 15.8]
num_pirates = [45000, 20000, 15000, 5000, 400, 17]
# Out:
# 6-element Vector{Int64}:
#  45000
#  20000
#  15000
#   5000
#    400
#     17

# %%
plot(num_pirates, global_temps, legend=false)
scatter!(num_pirates, global_temps, legend=false)

xflip!()

xlabel!("Num Pirates")
ylabel!("Global Temps")
title!("Influence of pirates on temps")

# %%
# creating subplots is also trivial
p1 = plot(x, x)
p2 = plot(x, x.^2)
p3 = plot(x, x.^3)
p4 = plot(x, x.^4)
plot(p1, p2, p3, p4, layout=(2, 2), legend=false)
